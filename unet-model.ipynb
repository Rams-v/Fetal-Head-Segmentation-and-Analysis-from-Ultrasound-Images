# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
path2train="/kaggle/input/fetal-head-ultrasound/training_set/training_set"

imgsList = [pp for pp in os.listdir(path2train) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
anntsList=[pp for pp in os.listdir(path2train) if "Annotation" in pp]
print("number of images:", len(imgsList))
print("number of annotations:", len(anntsList))
# Out:
# number of images: 999
# number of annotations: 999

# %%
import numpy as np
np.random.seed(2019)
rndImgs=np.random.choice(imgsList,4)
rndImgs
# Out:
# array(['584_HC.png', '169_HC.png', '741_HC.png', '579_2HC.png'],
#       dtype='<U11')

# %%
import matplotlib.pylab as plt
from PIL import Image
from scipy import ndimage as ndi
from skimage.segmentation import mark_boundaries
from torchvision.transforms.functional import to_tensor, to_pil_image
import torch

def show_img_mask(img, mask):
    if torch.is_tensor(img):
        img=to_pil_image(img)
        mask=to_pil_image(mask)
        
        
    img_mask=mark_boundaries(np.array(img), 
                        np.array(mask),
                        outline_color=(0,1,0),
                        color=(0,1,0))
    plt.imshow(img_mask)

# %%
for fn in rndImgs:
    path2img = os.path.join(path2train, fn)
    path2annt= path2img.replace(".png", "_Annotation.png")
    img = Image.open(path2img)
    annt_edges = Image.open(path2annt)
    mask = ndi.binary_fill_holes(annt_edges)        

    plt.figure()
    plt.subplot(1, 3, 1) 
    plt.imshow(img, cmap="gray")

    plt.subplot(1, 3, 2) 
    plt.imshow(mask, cmap="gray")

    plt.subplot(1, 3, 3) 
    show_img_mask(img, mask)

# %%
plt.figure()
plt.subplot(1, 3, 1) 
plt.imshow(img, cmap="gray")
plt.axis('off')

plt.subplot(1, 3, 2) 
plt.imshow(mask, cmap="gray")
plt.axis('off')    

plt.subplot(1, 3, 3) 
show_img_mask(img, mask)
plt.axis('off')
# Out:
# (-0.5, 799.5, 539.5, -0.5)

# %%
from albumentations import (
    HorizontalFlip,
    VerticalFlip,    
    Compose,
    Resize,
)

h,w=128,192
transform_train = Compose([ Resize(h,w), 
                HorizontalFlip(p=0.5), 
                VerticalFlip(p=0.5), 
              ])


transform_val = Resize(h,w)

# %%
from torch.utils.data import Dataset
from PIL import Image

# %%
from torchvision.transforms.functional import to_tensor, to_pil_image

class fetal_dataset(Dataset):
    def __init__(self, path2data, transform=None):      

        imgsList = [pp for pp in os.listdir(path2data) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
        anntsList=[pp for pp in os.listdir(path2train) if "Annotation" in pp]

        self.path2imgs = [os.path.join(path2data, fn) for fn in imgsList] 
        self.path2annts= [p2i.replace(".png", "_Annotation.png") for p2i in self.path2imgs]

        self.transform = transform
    
    def __len__(self):
        return len(self.path2imgs)
      
    def __getitem__(self, idx):
        path2img = self.path2imgs[idx]
        image = Image.open(path2img)

        path2annt = self.path2annts[idx]
        annt_edges = Image.open(path2annt)
        mask = ndi.binary_fill_holes(annt_edges)        
        
        image= np.array(image)
        mask=mask.astype("uint8")        

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']            

        image= to_tensor(image)            
        mask=255*to_tensor(mask)            
        return image, mask

# %%
fetal_ds1=fetal_dataset(path2train, transform=transform_train)
fetal_ds2=fetal_dataset(path2train, transform=transform_val)
print(len(fetal_ds1))
print(len(fetal_ds2))
# Out:
# 999
# 999

# %%
img,mask=fetal_ds1[0]
print(img.shape, img.type(),torch.max(img))
print(mask.shape, mask.type(),torch.max(mask))
# Out:
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(0.9529)
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(1.)

# %%
show_img_mask(img, mask)

# %%
from sklearn.model_selection import ShuffleSplit

sss = ShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices=range(len(fetal_ds1))

for train_index, val_index in sss.split(indices):
    print(len(train_index))
    print("-"*10)
    print(len(val_index))
# Out:
# 799
# ----------
# 200

# %%
from torch.utils.data import Subset

train_ds=Subset(fetal_ds1,train_index)
print(len(train_ds))

val_ds=Subset(fetal_ds2,val_index)
print(len(val_ds))
# Out:
# 799
# 200

# %%
plt.figure(figsize=(5,5))
for img,mask in train_ds:
    show_img_mask(img,mask)
    break

# %%
plt.figure(figsize=(5,5))
for img,mask in val_ds:
    show_img_mask(img,mask)
    break

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size=8, shuffle=False, pin_memory=True)

# %%
for img_b, mask_b in train_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([4, 1, 128, 192]) torch.float32
# torch.Size([4, 1, 128, 192]) torch.float32

# %%
for img_b, mask_b in val_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32

# %%
torch.max(img_b)
# Out:
# tensor(0.9961)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class SegNet(nn.Module):
    def __init__(self, params):
        super(SegNet, self).__init__()
        
        C_in, H_in, W_in=params["input_shape"]
        init_f=params["initial_filters"] 
        num_outputs=params["num_outputs"] 

        self.conv1 = nn.Conv2d(C_in, init_f, kernel_size=3,stride=1,padding=1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3,stride=1,padding=1)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv5 = nn.Conv2d(8*init_f, 16*init_f, kernel_size=3,padding=1)

        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)

        self.conv_up1 = nn.Conv2d(16*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv_up2 = nn.Conv2d(8*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv_up3 = nn.Conv2d(4*init_f, 2*init_f, kernel_size=3,padding=1)
        self.conv_up4 = nn.Conv2d(2*init_f, init_f, kernel_size=3,padding=1)

        self.conv_out = nn.Conv2d(init_f, num_outputs , kernel_size=3,padding=1)    
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv4(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv5(x)
        x = F.relu(x)

        x=self.upsample(x)
        x = self.conv_up1(x)
        x = F.relu(x)

        x=self.upsample(x)
        x = self.conv_up2(x)
        x = F.relu(x)
        
        x=self.upsample(x)
        x = self.conv_up3(x)
        x = F.relu(x)
        
        x=self.upsample(x)
        x = self.conv_up4(x)
        x = F.relu(x)

        x = self.conv_out(x)
        
        return x

# %%
params_model={
        "input_shape": (1,h,w),
        "initial_filters": 16, 
        "num_outputs": 1,
            }

model = SegNet(params_model)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model=model.to(device)

# %%
print(model)
# Out:
# SegNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#   (conv_up1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_out): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
from torchsummary import summary
summary(model, input_size=(1, h, w))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 192]             160
#             Conv2d-2           [-1, 32, 64, 96]           4,640
#             Conv2d-3           [-1, 64, 32, 48]          18,496
#             Conv2d-4          [-1, 128, 16, 24]          73,856
#             Conv2d-5           [-1, 256, 8, 12]         295,168
#           Upsample-6          [-1, 256, 16, 24]               0
#             Conv2d-7          [-1, 128, 16, 24]         295,040
#           Upsample-8          [-1, 128, 32, 48]               0
#             Conv2d-9           [-1, 64, 32, 48]          73,792
#          Upsample-10           [-1, 64, 64, 96]               0
#            Conv2d-11           [-1, 32, 64, 96]          18,464
#          Upsample-12         [-1, 32, 128, 192]               0
#            Conv2d-13         [-1, 16, 128, 192]           4,624
#            Conv2d-14          [-1, 1, 128, 192]             145
# ================================================================
# Total params: 784,385
# Trainable params: 784,385
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.09
# Forward/backward pass size (MB): 22.88
# Params size (MB): 2.99
# Estimated Total Size (MB): 25.96
# ----------------------------------------------------------------

# %%
def dice_loss(pred, target, smooth = 1e-5):

    intersection = (pred * target).sum(dim=(2,3))
    union= pred.sum(dim=(2,3)) + target.sum(dim=(2,3)) 
    
    dice= 2.0 * (intersection + smooth) / (union+ smooth)    
    loss = 1.0 - dice
    
    return loss.sum(), dice.sum()

# %%
import torch.nn.functional as F

def loss_func(pred, target):
    bce = F.binary_cross_entropy_with_logits(pred, target,  reduction='sum')
    
    pred= torch.sigmoid(pred)
    dlv, _ = dice_loss(pred, target)
    
    loss = bce  + dlv

    return loss

# %%
for img_v,mask_v in val_dl:
    mask_v= mask_v[8:]
    break

for img_t,mask_t in train_dl:
    break
    


print(dice_loss(mask_v,mask_v))
loss_func(mask_v,torch.zeros_like(mask_v))
# Out:
# (tensor(0.), tensor(0.))
# tensor(0.)

# %%
import torchvision

def metrics_batch(pred, target):
    pred= torch.sigmoid(pred)
    _, metric=dice_loss(pred, target)
    
    return metric

# %%
def loss_batch(loss_func, output, target, opt=None):   
    loss = loss_func(output, target)
    
    with torch.no_grad():
        pred= torch.sigmoid(output)
        _, metric_b=dice_loss(pred, target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %%
from torch import optim
opt = optim.Adam(model.parameters(), lr=3e-4)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0003

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss=0.0
    running_metric=0.0
    len_data=len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb=xb.to(device)
        yb=yb.to(device)
        
        output=model(xb)
        loss_b, metric_b=loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        
        if metric_b is not None:
            running_metric+=metric_b

        if sanity_check is True:
            break
    
    loss=running_loss/float(len_data)
    
    metric=running_metric/float(len_data)
    
    return loss, metric

# %%
import copy
import time
def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    loss_history={
        "train": [],
        "val": []}
    
    metric_history={
        "train": [],
        "val": []}    
    
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss=float('inf')    
    
    for epoch in range(num_epochs):
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   
        
        start_time = time.time()
        
        model.train()
        train_loss, train_metric=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_metric=loss_epoch(model,loss_func,val_dl,sanity_check)
       
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)   
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            
        epoch_time = time.time() - start_time
        print("train loss: %.6f, dice: %.2f" %(train_loss,100*train_metric))
        print("val loss: %.6f, dice: %.2f" %(val_loss,100*val_metric))
        print("Epoch Time: %.2f seconds".format(epoch_time))
        print("-"*10) 
        

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
opt = optim.Adam(model.parameters(), lr=3e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models= "./models/"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train={
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": False,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models+"weights.pt",
}

model,loss_hist,metric_hist=train_val(model,params_train)
# Out:
# Epoch 0/99, current lr=0.0003
# Copied best model weights!
# train loss: 9343.003580, dice: 55.22
# val loss: 5780.450820, dice: 72.96
# Epoch Time: %.2f seconds
# ----------
# Epoch 1/99, current lr=0.0003
# Copied best model weights!
# train loss: 4985.548045, dice: 76.07
# val loss: 4061.983057, dice: 81.84
# Epoch Time: %.2f seconds
# ----------
# Epoch 2/99, current lr=0.0003
# Copied best model weights!
# train loss: 3604.890002, dice: 81.97
# val loss: 3300.598657, dice: 83.61
# Epoch Time: %.2f seconds
# ----------
# Epoch 3/99, current lr=0.0003
# Copied best model weights!
# train loss: 2785.729206, dice: 85.89
# val loss: 2683.218574, dice: 84.90
# Epoch Time: %.2f seconds
# ----------
# Epoch 4/99, current lr=0.0003
# Copied best model weights!
# train loss: 2276.328497, dice: 88.38
# val loss: 2155.384766, dice: 89.66
# Epoch Time: %.2f seconds
# ----------
# Epoch 5/99, current lr=0.0003
# Copied best model weights!
# train loss: 2023.920299, dice: 89.96
# val loss: 1962.268511, dice: 89.97
# Epoch Time: %.2f seconds
# ----------
# Epoch 6/99, current lr=0.0003
# Copied best model weights!
# train loss: 1815.135237, dice: 90.88
# val loss: 1784.914907, dice: 91.41
# Epoch Time: %.2f seconds
# ----------
# Epoch 7/99, current lr=0.0003
# train loss: 1713.520874, dice: 91.53
# val loss: 1790.778091, dice: 91.28
# Epoch Time: %.2f seconds
# ----------
# Epoch 8/99, current lr=0.0003
# Copied best model weights!
# train loss: 1649.715235, dice: 91.93
# val loss: 1569.766604, dice: 92.34
# Epoch Time: %.2f seconds
# ----------
# Epoch 9/99, current lr=0.0003
# Copied best model weights!
# train loss: 1533.866271, dice: 92.47
# val loss: 1547.555918, dice: 92.36
# Epoch Time: %.2f seconds
# ----------
# Epoch 10/99, current lr=0.0003
# Copied best model weights!
# train loss: 1556.301138, dice: 92.49
# val loss: 1532.337385, dice: 92.34
# Epoch Time: %.2f seconds
# ----------
# Epoch 11/99, current lr=0.0003
# train loss: 1495.568309, dice: 92.90
# val loss: 1596.903867, dice: 91.77
# Epoch Time: %.2f seconds
# ----------
# Epoch 12/99, current lr=0.0003
# train loss: 1595.316931, dice: 92.11
# val loss: 1623.142261, dice: 91.59
# Epoch Time: %.2f seconds
# ----------
# Epoch 13/99, current lr=0.0003
# train loss: 1481.049804, dice: 92.80
# val loss: 1574.360823, dice: 91.56
# Epoch Time: %.2f seconds
# ----------
# Epoch 14/99, current lr=0.0003
# Copied best model weights!
# train loss: 1382.688433, dice: 93.08
# val loss: 1396.128462, dice: 93.06
# Epoch Time: %.2f seconds
# ----------
# Epoch 15/99, current lr=0.0003
# train loss: 1419.451135, dice: 93.16
# val loss: 1562.737200, dice: 93.00
# Epoch Time: %.2f seconds
# ----------
# Epoch 16/99, current lr=0.0003
# Copied best model weights!
# train loss: 1359.290212, dice: 93.46
# val loss: 1348.918254, dice: 93.39
# Epoch Time: %.2f seconds
# ----------
# Epoch 17/99, current lr=0.0003
# train loss: 1283.693473, dice: 93.69
# val loss: 1397.134739, dice: 93.36
# Epoch Time: %.2f seconds
# ----------
# Epoch 18/99, current lr=0.0003
# train loss: 1266.751263, dice: 93.87
# val loss: 1565.767563, dice: 93.10
# Epoch Time: %.2f seconds
# ----------
# Epoch 19/99, current lr=0.0003
# Copied best model weights!
# train loss: 1197.230782, dice: 94.12
# val loss: 1283.822202, dice: 94.07
# Epoch Time: %.2f seconds
# ----------
# Epoch 20/99, current lr=0.0003
# train loss: 1200.236799, dice: 94.25
# val loss: 1392.254341, dice: 93.44
# Epoch Time: %.2f seconds
# ----------
# Epoch 21/99, current lr=0.0003
# Copied best model weights!
# train loss: 1236.758575, dice: 94.10
# val loss: 1237.985303, dice: 94.12
# Epoch Time: %.2f seconds
# ----------
# Epoch 22/99, current lr=0.0003
# train loss: 1214.424508, dice: 94.31
# val loss: 1395.354282, dice: 92.80
# Epoch Time: %.2f seconds
# ----------
# Epoch 23/99, current lr=0.0003
# train loss: 1138.237539, dice: 94.41
# val loss: 1286.837029, dice: 94.33
# Epoch Time: %.2f seconds
# ----------
# Epoch 24/99, current lr=0.0003
# train loss: 1181.370810, dice: 94.28
# val loss: 1302.460735, dice: 94.39
# Epoch Time: %.2f seconds
# ----------
# Epoch 25/99, current lr=0.0003
# train loss: 1210.679076, dice: 94.33
# val loss: 1391.264773, dice: 93.33
# Epoch Time: %.2f seconds
# ----------
# Epoch 26/99, current lr=0.0003
# train loss: 1075.370903, dice: 94.58
# val loss: 1298.750293, dice: 93.92
# Epoch Time: %.2f seconds
# ----------
# Epoch 27/99, current lr=0.0003
# train loss: 1143.800753, dice: 94.52
# val loss: 1247.892302, dice: 94.43
# Epoch Time: %.2f seconds
# ----------
# Epoch 28/99, current lr=0.0003
# Copied best model weights!
# train loss: 1016.988710, dice: 94.92
# val loss: 1214.525100, dice: 94.14
# Epoch Time: %.2f seconds
# ----------
# Epoch 29/99, current lr=0.0003
# Copied best model weights!
# train loss: 1114.152806, dice: 94.67
# val loss: 1145.121963, dice: 94.53
# Epoch Time: %.2f seconds
# ----------
# Epoch 30/99, current lr=0.0003
# train loss: 1000.948513, dice: 95.09
# val loss: 1200.696709, dice: 94.20
# Epoch Time: %.2f seconds
# ----------
# Epoch 31/99, current lr=0.0003
# train loss: 1008.157957, dice: 94.89
# val loss: 1211.585640, dice: 94.54
# Epoch Time: %.2f seconds
# ----------
# Epoch 32/99, current lr=0.0003
# train loss: 976.126312, dice: 95.09
# val loss: 1158.558079, dice: 94.79
# Epoch Time: %.2f seconds
# ----------
# Epoch 33/99, current lr=0.0003
# train loss: 942.524511, dice: 95.19
# val loss: 1146.389067, dice: 94.81
# Epoch Time: %.2f seconds
# ----------
# Epoch 34/99, current lr=0.0003
# train loss: 1061.406227, dice: 94.61
# val loss: 1202.972700, dice: 94.38
# Epoch Time: %.2f seconds
# ----------
# Epoch 35/99, current lr=0.0003
# train loss: 984.898583, dice: 95.06
# val loss: 1220.450759, dice: 94.44
# Epoch Time: %.2f seconds
# ----------
# Epoch 36/99, current lr=0.0003
# train loss: 915.245499, dice: 95.28
# val loss: 1190.373870, dice: 94.87
# Epoch Time: %.2f seconds
# ----------
# Epoch 37/99, current lr=0.0003
# train loss: 913.142966, dice: 95.31
# val loss: 1145.196436, dice: 94.82
# Epoch Time: %.2f seconds
# ----------
# Epoch 38/99, current lr=0.0003
# Copied best model weights!
# train loss: 943.889878, dice: 95.28
# val loss: 1142.205059, dice: 95.02
# Epoch Time: %.2f seconds
# ----------
# Epoch 39/99, current lr=0.0003
# train loss: 910.729952, dice: 95.51
# val loss: 1399.192532, dice: 94.60
# Epoch Time: %.2f seconds
# ----------
# Epoch 40/99, current lr=0.0003
# Copied best model weights!
# train loss: 841.004218, dice: 95.63
# val loss: 1135.327085, dice: 95.29
# Epoch Time: %.2f seconds
# ----------
# Epoch 41/99, current lr=0.0003
# train loss: 806.901251, dice: 95.78
# val loss: 1193.819434, dice: 94.96
# Epoch Time: %.2f seconds
# ----------
# Epoch 42/99, current lr=0.0003
# train loss: 775.631914, dice: 95.88
# val loss: 1186.074155, dice: 95.35
# Epoch Time: %.2f seconds
# ----------
# Epoch 43/99, current lr=0.0003
# train loss: 789.391635, dice: 95.82
# val loss: 1154.508567, dice: 95.18
# Epoch Time: %.2f seconds
# ----------
# Epoch 44/99, current lr=0.0003
# train loss: 851.830078, dice: 95.68
# val loss: 1307.923274, dice: 94.05
# Epoch Time: %.2f seconds
# ----------
# Epoch 45/99, current lr=0.0003
# train loss: 908.303069, dice: 95.35
# val loss: 1464.832830, dice: 94.12
# Epoch Time: %.2f seconds
# ----------
# Epoch 46/99, current lr=0.0003
# train loss: 781.358163, dice: 95.79
# val loss: 1219.328870, dice: 95.31
# Epoch Time: %.2f seconds
# ----------
# Epoch 47/99, current lr=0.0003
# train loss: 831.940287, dice: 95.67
# val loss: 1241.455608, dice: 94.58
# Epoch Time: %.2f seconds
# ----------
# Epoch 48/99, current lr=0.0003
# train loss: 738.983708, dice: 96.05
# val loss: 1194.409043, dice: 95.02
# Epoch Time: %.2f seconds
# ----------
# Epoch 49/99, current lr=0.0003
# train loss: 730.307424, dice: 96.12
# val loss: 1233.857141, dice: 95.16
# Epoch Time: %.2f seconds
# ----------
# Epoch 50/99, current lr=0.0003
# train loss: 723.417293, dice: 96.16
# val loss: 1253.062517, dice: 95.17
# Epoch Time: %.2f seconds
# ----------
# Epoch 51/99, current lr=0.0003
# train loss: 706.441582, dice: 96.19
# val loss: 1246.672427, dice: 95.30
# Epoch Time: %.2f seconds
# ----------
# Epoch 52/99, current lr=0.0003
# train loss: 686.466569, dice: 96.31
# val loss: 1274.456641, dice: 95.33
# Epoch Time: %.2f seconds
# ----------
# Epoch 53/99, current lr=0.0003
# train loss: 709.842506, dice: 96.18
# val loss: 1295.705203, dice: 95.25
# Epoch Time: %.2f seconds
# ----------
# Epoch 54/99, current lr=0.0003
# train loss: 701.700116, dice: 96.30
# val loss: 1277.640903, dice: 95.05
# Epoch Time: %.2f seconds
# ----------
# Epoch 55/99, current lr=0.0003
# train loss: 694.406385, dice: 96.25
# val loss: 1222.371863, dice: 95.29
# Epoch Time: %.2f seconds
# ----------
# Epoch 56/99, current lr=0.0003
# train loss: 661.139325, dice: 96.44
# val loss: 1278.207185, dice: 95.49
# Epoch Time: %.2f seconds
# ----------
# Epoch 57/99, current lr=0.0003
# train loss: 662.436414, dice: 96.44
# val loss: 1241.043589, dice: 95.43
# Epoch Time: %.2f seconds
# ----------
# Epoch 58/99, current lr=0.0003
# train loss: 754.594242, dice: 96.13
# val loss: 1187.219856, dice: 94.89
# Epoch Time: %.2f seconds
# ----------
# Epoch 59/99, current lr=0.0003
# train loss: 684.351330, dice: 96.28
# val loss: 1275.868438, dice: 95.45
# Epoch Time: %.2f seconds
# ----------
# Epoch 60/99, current lr=0.0003
# train loss: 652.885445, dice: 96.50
# val loss: 1312.873235, dice: 95.47
# Epoch Time: %.2f seconds
# ----------
# Epoch 61/99, current lr=0.0003
# Loading best model weights!
# train loss: 624.393434, dice: 96.61
# val loss: 1284.000752, dice: 95.48
# Epoch Time: %.2f seconds
# ----------
# Epoch 62/99, current lr=0.00015
# train loss: 779.311673, dice: 95.84
# val loss: 1185.809031, dice: 95.10
# Epoch Time: %.2f seconds
# ----------
# Epoch 63/99, current lr=0.00015
# train loss: 755.942946, dice: 96.00
# val loss: 1149.686294, dice: 95.17
# Epoch Time: %.2f seconds
# ----------
# Epoch 64/99, current lr=0.00015
# train loss: 807.755067, dice: 95.87
# val loss: 1169.822239, dice: 95.33
# Epoch Time: %.2f seconds
# ----------
# Epoch 65/99, current lr=0.00015
# train loss: 794.578872, dice: 95.85
# val loss: 1162.478364, dice: 95.16
# Epoch Time: %.2f seconds
# ----------
# Epoch 66/99, current lr=0.00015
# train loss: 734.894079, dice: 96.13
# val loss: 1184.055999, dice: 95.32
# Epoch Time: %.2f seconds
# ----------
# Epoch 67/99, current lr=0.00015
# train loss: 725.127797, dice: 96.16
# val loss: 1197.423645, dice: 95.43
# Epoch Time: %.2f seconds
# ----------
# Epoch 68/99, current lr=0.00015
# train loss: 707.143543, dice: 96.26
# val loss: 1193.753315, dice: 95.42
# Epoch Time: %.2f seconds
# ----------
# Epoch 69/99, current lr=0.00015
# train loss: 683.708022, dice: 96.32
# val loss: 1210.127102, dice: 95.54
# Epoch Time: %.2f seconds
# ----------
# Epoch 70/99, current lr=0.00015
# train loss: 679.470236, dice: 96.37
# val loss: 1198.238157, dice: 95.45
# Epoch Time: %.2f seconds
# ----------
# Epoch 71/99, current lr=0.00015
# train loss: 671.617325, dice: 96.40
# val loss: 1248.325925, dice: 95.45
# Epoch Time: %.2f seconds
# ----------
# Epoch 72/99, current lr=0.00015
# train loss: 659.557413, dice: 96.47
# val loss: 1232.451284, dice: 95.45
# Epoch Time: %.2f seconds
# ----------
# Epoch 73/99, current lr=0.00015
# train loss: 649.882679, dice: 96.51
# val loss: 1242.776667, dice: 95.65
# Epoch Time: %.2f seconds
# ----------
# Epoch 74/99, current lr=0.00015
# train loss: 654.328363, dice: 96.49
# val loss: 1307.626665, dice: 95.22
# Epoch Time: %.2f seconds
# ----------
# Epoch 75/99, current lr=0.00015
# train loss: 645.981104, dice: 96.53
# val loss: 1270.459622, dice: 95.51
# Epoch Time: %.2f seconds
# ----------
# Epoch 76/99, current lr=0.00015
# train loss: 644.675104, dice: 96.54
# val loss: 1251.640364, dice: 95.48
# Epoch Time: %.2f seconds
# ----------
# Epoch 77/99, current lr=0.00015
# train loss: 656.156200, dice: 96.49
# val loss: 1281.167307, dice: 95.46
# Epoch Time: %.2f seconds
# ----------
# Epoch 78/99, current lr=0.00015
# train loss: 624.843321, dice: 96.62
# val loss: 1299.506753, dice: 95.46
# Epoch Time: %.2f seconds
# ----------
# Epoch 79/99, current lr=0.00015
# train loss: 616.841998, dice: 96.68
# val loss: 1304.949517, dice: 95.53
# Epoch Time: %.2f seconds
# ----------
# Epoch 80/99, current lr=0.00015
# train loss: 613.904665, dice: 96.67
# val loss: 1317.480525, dice: 95.63
# Epoch Time: %.2f seconds
# ----------
# Epoch 81/99, current lr=0.00015
# train loss: 596.401346, dice: 96.75
# val loss: 1335.320620, dice: 95.68
# Epoch Time: %.2f seconds
# ----------
# Epoch 82/99, current lr=0.00015
# Loading best model weights!
# train loss: 606.269874, dice: 96.74
# val loss: 1410.152026, dice: 95.49
# Epoch Time: %.2f seconds
# ----------
# Epoch 83/99, current lr=7.5e-05
# train loss: 795.997543, dice: 95.84
# val loss: 1157.375737, dice: 95.34
# Epoch Time: %.2f seconds
# ----------
# Epoch 84/99, current lr=7.5e-05
# train loss: 747.799636, dice: 96.07
# val loss: 1168.047385, dice: 95.31
# Epoch Time: %.2f seconds
# ----------
# Epoch 85/99, current lr=7.5e-05
# train loss: 753.281595, dice: 96.09
# val loss: 1166.347957, dice: 95.07
# Epoch Time: %.2f seconds
# ----------
# Epoch 86/99, current lr=7.5e-05
# train loss: 721.785456, dice: 96.14
# val loss: 1144.428403, dice: 95.43
# Epoch Time: %.2f seconds
# ----------
# Epoch 87/99, current lr=7.5e-05
# train loss: 704.742750, dice: 96.26
# val loss: 1154.204634, dice: 95.41
# Epoch Time: %.2f seconds
# ----------
# Epoch 88/99, current lr=7.5e-05
# train loss: 702.587235, dice: 96.26
# val loss: 1191.886426, dice: 95.41
# Epoch Time: %.2f seconds
# ----------
# Epoch 89/99, current lr=7.5e-05
# train loss: 687.691848, dice: 96.35
# val loss: 1207.819153, dice: 95.37
# Epoch Time: %.2f seconds
# ----------
# Epoch 90/99, current lr=7.5e-05
# train loss: 686.636653, dice: 96.33
# val loss: 1184.790090, dice: 95.50
# Epoch Time: %.2f seconds
# ----------
# Epoch 91/99, current lr=7.5e-05
# train loss: 681.929128, dice: 96.37
# val loss: 1204.329956, dice: 95.50
# Epoch Time: %.2f seconds
# ----------
# Epoch 92/99, current lr=7.5e-05
# train loss: 666.292917, dice: 96.45
# val loss: 1175.087942, dice: 95.50
# Epoch Time: %.2f seconds
# ----------
# Epoch 93/99, current lr=7.5e-05
# train loss: 672.428077, dice: 96.40
# val loss: 1180.771057, dice: 95.49
# Epoch Time: %.2f seconds
# ----------
# Epoch 94/99, current lr=7.5e-05
# train loss: 660.131199, dice: 96.46
# val loss: 1207.920195, dice: 95.55
# Epoch Time: %.2f seconds
# ----------
# Epoch 95/99, current lr=7.5e-05
# train loss: 654.428770, dice: 96.48
# val loss: 1259.273306, dice: 95.60
# Epoch Time: %.2f seconds
# ----------
# Epoch 96/99, current lr=7.5e-05
# train loss: 652.204373, dice: 96.51
# val loss: 1252.650935, dice: 95.48
# Epoch Time: %.2f seconds
# ----------
# Epoch 97/99, current lr=7.5e-05
# train loss: 637.348112, dice: 96.57
# val loss: 1268.560486, dice: 95.49
# Epoch Time: %.2f seconds
# ----------
# Epoch 98/99, current lr=7.5e-05
# train loss: 629.291796, dice: 96.62
# val loss: 1251.490354, dice: 95.60
# Epoch Time: %.2f seconds
# ----------
# Epoch 99/99, current lr=7.5e-05
# train loss: 639.564548, dice: 96.57
# val loss: 1230.820742, dice: 95.63
# Epoch Time: %.2f seconds
# ----------

# %%
num_epochs=params_train["num_epochs"]

plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
import os
path2test="/kaggle/input/fetal-head-ultrasound/test_set/test_set"
imgsList=[pp for pp in os.listdir(path2test) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
print("number of images:", len(imgsList))
# Out:
# number of images: 335

# %%
import numpy as np
np.random.seed(2019)
rndImgs=np.random.choice(imgsList,4)
rndImgs
# Out:
# array(['61_HC.png', '259_HC.png', '117_HC.png', '186_3HC.png'],
#       dtype='<U11')

# %%
path2weights="/kaggle/working/models/weights.pt"
model.load_state_dict(torch.load(path2weights))
model.eval()
# Out:
# <ipython-input-128-c931974a8628>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path2weights))
# SegNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#   (conv_up1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_out): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
from torchvision.transforms.functional import to_tensor, to_pil_image

for fn in rndImgs:
    path2img = os.path.join(path2test, fn)
    img = Image.open(path2img)
    img=img.resize((w,h))
    img_t=to_tensor(img).unsqueeze(0).to(device)
    
    #model(img_test.unsqueeze(0).cuda()).cpu()
    
    pred = model(img_t).cpu()

    pred=torch.sigmoid(pred)[0]
    mask_pred= (pred[0]>=0.5)

    plt.figure()
    plt.subplot(1, 3, 1) 
    plt.imshow(img, cmap="gray")

    plt.subplot(1, 3, 2) 
    plt.imshow(mask_pred, cmap="gray")
    
    plt.subplot(1, 3, 3) 
    show_img_mask(img, mask_pred)

# %%
import skimage.filters
import skimage.measure

for fn in rndImgs:
    path2img = os.path.join(path2test, fn)
    img = Image.open(path2img)
    img = img.resize((w, h))
    img_t = to_tensor(img).unsqueeze(0).to(device)

    pred = model(img_t).cpu()
    pred = torch.sigmoid(pred)[0]
    mask_pred = (pred[0] >= 0.5)
    
    image_gray = mask_pred.numpy().astype('uint8') * 255  # Convert the mask to grayscale

    thresh = skimage.filters.threshold_otsu(image_gray)
    tumor_mask = image_gray > thresh
    
    pixel_size = 0.1  # the size of a pixel in millimeters
    label_image = skimage.measure.label(tumor_mask)
    region_props = skimage.measure.regionprops(label_image)
    
    if len(region_props) == 0:
        tumor_size_mm = 0.0
    else:
        tumor_area = region_props[0].area
        tumor_size_mm = tumor_area * pixel_size ** 2

    plt.figure(figsize=(15, 5))  # Set the figure size to (15, 5)

    plt.subplot(1, 3, 1)
    plt.imshow(img, cmap="gray")
    plt.axis('off')

    plt.subplot(1, 3, 2)
    # plt.title(f"Tumor size: {tumor_size_mm:.2f} mm^2", fontsize=14)  # Display the tumor size on the plot
    plt.imshow(mask_pred, cmap="gray")
    plt.axis('off')

    plt.subplot(1, 3, 3)
    show_img_mask(img, mask_pred)
    plt.axis('off')

    plt.show()

# %%
`
